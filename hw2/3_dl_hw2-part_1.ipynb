# %% [markdown]
# # RL and Advanced DL: Домашнее задание 2
#
# ##  Содержание <a name = 'outline'></a>
#
# * [Часть I: крестики-нолики при помощи Q-обучения](#part_1)
#     * [Задание 1](#task_1)
#     * [Задание 2](#task_2)
#
# * [Часть II: добавим нейронных сетей](#port_2)
#     * [Задание 3](#task_3)
#     * [Задание 4](#task_4)

# %%
from tictactoe import TicTacToe
from agent_q import Player

# %% [markdown]
# ### Часть I: крестики-нолики при помощи Q-обучения <a name = "part_1"/>
#
# В коде, прилагающемся к последней лекции про обучение с подкреплением, реализован Environment для крестиков-ноликов, в котором можно при инициализации указывать разные размеры доски и условия победы, а также функции для рисования, в том числе с указанием оценки различных действий. С этим окружением все задания и связаны.

# %% [markdown]
# Environment для игры в крестики-нолики находится в [tictactoe.py](tictactoe.py)
# Агент реализующий стратегию находится в [agent_q.py](agent_q.py)

# %% [markdown]
# #### Задание 1  <a name = "task_1"/>
#
# Реализуйте обычное (табличное) Q-обучение. Обучите стратегии крестиков и ноликов для доски 3х3.

# %%
# %matplotlib notebook

board_cols, board_rows, num_counts = 3, 3, 3

player_1 = Player('p1',
                  board_cols,
                  board_rows,
                  exp_rate=0.3,
                  lr=0.05,
                  decay_gamma=0.8,
                  )
player_2 = Player('p2',
                  board_cols,
                  board_rows,
                  exp_rate=0.3,
                  lr=0.05,
                  decay_gamma=0.8,
                  )

game = TicTacToe(player_1,
                 player_2,
                 board_cols,
                 board_rows,
                 num_counts,
                 )

game.fit(rounds=int(1e5+1),
         delta_i_valid=int(1e4),
         n_test=int(1e3),
         set_change_expl=(0, 1),
         is_change_expl=(True, True),
         )
# Out:
# <img src="data:image/png;base64,..." width="800">
#   0%|          | 0/100001 [00:00<?, ?it/s]

# %% [markdown]
# #### Задание 2  <a name = "task_2"/>
# Попробуйте обучить стратегии крестиков и ноликов для доски 4х4 и/или 5х5.

# %%
# %matplotlib notebook

board_cols, board_rows, num_counts = 4, 4, 4

player_1 = Player('p1',
                  board_cols,
                  board_rows,
                  exp_rate=0.3,
                  lr=0.05,
                  decay_gamma=0.8,
                  )
player_2 = Player("p2",
                  board_cols,
                  board_rows,
                  exp_rate=0.3,
                  lr=0.05,
                  decay_gamma=0.8,
                  )

game = TicTacToe(player_1,
                 player_2,
                 board_cols,
                 board_rows,
                 num_counts,
                 )

game.fit(rounds=int(5e6+1),
         delta_i_valid=int(5e5),
         n_test=int(5e4),
         set_change_expl=(0, 1),
         is_change_expl=(True, True),
         )
# Out:
# <img src="data:image/png;base64,..." width="800">
#   0%|          | 0/5000001 [00:00<?, ?it/s]
